# %%
import pandas as pd

# %%
df = pd.read_csv('moviesdataset_2023.csv')

# %%
df
# Out:
#     Unnamed: 0                 name rating    votes  runtime  \
# 0            0          Oppenheimer    8.4  565,499  180 min
# 1            1     Sound of Freedom    7.7   91,802  131 min
# 2            2             Saltburn    7.3   38,572  131 min
# 3            3               Tetris    7.4   75,645  118 min
# 4            4     Jesus Revolution    7.1   12,613  120 min
# ..         ...                  ...    ...      ...      ...
# 95          95  The Pope's Exorcist    6.1   76,775  103 min
# 96          96            Creed III    6.7   87,908  116 min
# 97          97            Kidnapped    7.1    1,855  134 min
# 98          98               Fast X    5.8  106,548  141 min
# 99          99       The Mothership   none     None     None
#
#                         genre  \
# 0   Biography, Drama, History
# 1     Biography, Crime, Drama
# 2     Comedy, Drama, Thriller
# 3   Biography, Drama, History
# 4                       Drama
# ..                        ...
# 95           Horror, Thriller
# 96               Drama, Sport
# 97             Drama, History
# 98   Action, Adventure, Crime
# 99   Adventure, Drama, Family
#
#                                           description
# 0   ['The story of American scientist J. Robert Op...
# 1   ['The incredible true story of a former govern...
# 2   ["A student at Oxford University finds himself...
# 3   ["The story of how one of the world's most pop...
# 4   ['The true story of a national spiritual awake...
# ..                                                ...
# 95  ["Follow Gabriele Amorth, the Vatican's leadin...
# 96  ['Adonis has been thriving in both his career ...
# 97  ['A Jewish boy is kidnapped and converted to C...
# 98  ['Dom Toretto and his family are targeted by t...
# 99  ["One year after her husband's mysterious disa...
#
# [100 rows x 7 columns]

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from ast import literal_eval

df = pd.read_csv('moviesdataset_2023.csv')
# Convert the genre column to a list
df['genre'] = df['genre'].apply(literal_eval)

# Convert the list of genres to a space-separated string
df['genre'] = df['genre'].apply(lambda x: ' '.join(x))

# Create a TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer(stop_words='english')

# Create a TF-IDF matrix based on combined features
tfidf_matrix = tfidf_vectorizer.fit_transform(df['genre'] + ' ' + df['description'])

# Calculate weighted cosine similarity
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

# Function to get movie recommendations
def get_recommendations(movie_title, cosine_similarities=cosine_similarities, df=df):
    movie_index = df[df['name'] == movie_title].index[0]
    similarity_scores = list(enumerate(cosine_similarities[movie_index]))
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    similar_movies = similarity_scores[1:6]  # Exclude the movie itself, and get top 5
    recommended_movies = df.loc[[index[0] for index in similar_movies], 'name'].tolist()
    return recommended_movies

# Example usage
user_preference = 'Oppenheimer'
recommendations = get_recommendations(user_preference)
print(f"Recommended movies for '{user_preference}': {recommendations}")
# Out:
# Recommended movies for 'Oppenheimer': ['BlackBerry', 'Tetris', 'The Hill', 'Sound of Freedom', 'Poor Things']

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from ast import literal_eval

# Load the CSV data
df = pd.read_csv('moviesdataset_2023.csv')

# Convert the genre column to a list
df['genre'] = df['genre'].apply(literal_eval)

# Convert the list of genres to a space-separated string
df['genre'] = df['genre'].apply(lambda x: ' '.join(x))

# Prompt the user to choose a genre
print("Choose a genre:")
unique_genres = df['genre'].explode().unique()
for i, genre in enumerate(unique_genres, 1):
    print(f"{i}. {genre}")

selected_genre_index = int(input("Enter the number corresponding to your chosen genre: "))
selected_genre = unique_genres[selected_genre_index - 1]

# Filter movies by the selected genre
genre_filtered_df = df[df['genre'].str.contains(selected_genre)]

# Sort movies by vote count in descending order
sorted_df = genre_filtered_df.sort_values(by='votes', ascending=False)

# Display movies with the highest vote count in the selected genre
print(f"\nTop movies in the '{selected_genre}' genre based on vote count:")
print(sorted_df[['name', 'votes']].head())

# Ask the user to choose a movie from the displayed list
user_preference = input("Choose a movie from the list above: ")

# Create a TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer(stop_words='english')

# Create a TF-IDF matrix based on combined features
tfidf_matrix = tfidf_vectorizer.fit_transform(df['genre'] + ' ' + df['description'])

# Calculate weighted cosine similarity
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

# Function to get movie recommendations
def get_recommendations(movie_title, cosine_similarities=cosine_similarities, df=df):
    movie_index = df[df['name'] == movie_title].index[0]
    similarity_scores = list(enumerate(cosine_similarities[movie_index]))
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    similar_movies = similarity_scores[1:6]  # Exclude the movie itself, and get top 5
    recommended_movies = df.loc[[index[0] for index in similar_movies], 'name'].tolist()
    return recommended_movies

# Get recommendations based on user's choice
recommendations = get_recommendations(user_preference)
print(f"\nRecommended movies for '{user_preference}': {recommendations}")
# Out:
# Choose a genre:
# 1. Biography, Drama, History
# 2. Biography, Crime, Drama
# 3. Comedy, Drama, Thriller
# 4. Drama
# 5. Crime, Drama
# 6. Action, Sci-Fi, Thriller
# 7. Comedy, Music, Romance
# 8. Biography, Comedy, Drama
# 9. Drama, Sport
# 10. Action, Drama, Thriller
# 11. Comedy, History
# 12. Drama, Romance
# 13. Comedy, Romance
# 14. Crime, Drama, Thriller
# 15. Action, Drama, War
# 16. Comedy, Drama
# 17. Action, Adventure, Drama
# 18. Animation, Action, Adventure
# 19. Action, War
# 20. Biography, Drama, Sport
# 21. Comedy, Drama, Sport
# 22. Horror, Sci-Fi, Thriller
# 23. Action, Crime, Drama
# 24. Action, Adventure, History
# 25. Crime, Drama, History
# 26. Action, Adventure, Comedy
# 27. Action, Adventure, Thriller
# 28. Drama, Mystery, Thriller
# 29. Action, Crime, Thriller
# 30. Horror
# 31. Crime, Drama, Mystery
# 32. Action, Adventure, Sci-Fi
# 33. Horror, Thriller
# 34. Animation, Adventure, Comedy
# 35. Action, Thriller
# 36. Biography, Drama
# 37. Documentary, Biography
# 38. Comedy, Drama, Romance
# 39. Comedy, Horror
# 40. Adventure, Comedy, Fantasy
# 41. Comedy, Drama, Family
# 42. Sci-Fi, Thriller
# 43. Adventure, Family, Fantasy
# 44. Comedy
# 45. Comedy, Drama, Sci-Fi
# 46. Action, Crime, History
# 47. Crime, Horror, Mystery
# 48. Horror, Mystery, Thriller
# 49. Drama, History, Thriller
# 50. Drama, Thriller
# 51. Action, Adventure, Fantasy
# 52. Crime, Drama, Horror
# 53. Action, Comedy, Thriller
# 54. Action, Adventure, Mystery
# 55. Comedy, Fantasy, Horror
# 56. Action, Adventure, Biography
# 57. Drama, History
# 58. Action, Adventure, Crime
# 59. Adventure, Drama, Family
# Enter the number corresponding to your chosen genre: 44
#
# Top movies in the 'Comedy' genre based on vote count:
#                                      name   votes
# 87                          Asteroid City  93,356
# 92                               Renfield  85,168
# 90      Operation Fortune: Ruse de Guerre  78,165
# 60  Are You There God? It's Me, Margaret.  74,465
# 71                                  Jules   7,452
# Choose a movie from the list above: Jules
#
# Recommended movies for 'Jules': ['M3GAN', 'Paradise', '57 Seconds', 'No One Will Save You', 'Flora and Son']

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from ast import literal_eval

# Load the CSV data
df = pd.read_csv('moviesdataset_2023.csv')

# Convert the genre column to a list
df['genre'] = df['genre'].apply(literal_eval)

# Convert the list of genres to a space-separated string
df['genre'] = df['genre'].apply(lambda x: ' '.join(x))

# Prompt the user to choose between entering a movie or selecting a genre
print("Choose an option:")
print("1. Enter a movie")
print("2. Choose a genre")

option = int(input("Enter the number corresponding to your choice: "))

if option == 1:
    # User enters a movie
    user_preference = input("Enter a movie: ")

else:
    # User chooses a genre
    print("\nChoose a genre:")
    unique_genres = df['genre'].explode().unique()
    for i, genre in enumerate(unique_genres, 1):
        print(f"{i}. {genre}")

    selected_genre_index = int(input("Enter the number corresponding to your chosen genre: "))
    selected_genre = unique_genres[selected_genre_index - 1]

    # Filter movies by the selected genre
    genre_filtered_df = df[df['genre'].str.contains(selected_genre)]

    # Sort movies by vote count in descending order
    sorted_df = genre_filtered_df.sort_values(by='votes', ascending=False)

    # Display movies with the highest vote count in the selected genre
    print(f"\nTop movies in the '{selected_genre}' genre based on vote count:")
    print(sorted_df[['name', 'votes']].head())

    # Ask the user to choose a movie from the displayed list
    user_preference = input("Choose a movie from the list above: ")

# Create a TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer(stop_words='english')

# Create a TF-IDF matrix based on combined features
tfidf_matrix = tfidf_vectorizer.fit_transform(df['genre'] + ' ' + df['description'])

# Calculate weighted cosine similarity
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

# Function to get movie recommendations
def get_recommendations(movie_title, cosine_similarities=cosine_similarities, df=df):
    movie_index = df[df['name'] == movie_title].index[0]
    similarity_scores = list(enumerate(cosine_similarities[movie_index]))
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    similar_movies = similarity_scores[1:6]  # Exclude the movie itself, and get top 5
    recommended_movies = df.loc[[index[0] for index in similar_movies], 'name'].tolist()
    return recommended_movies

# Get recommendations based on user's choice
recommendations = get_recommendations(user_preference)
print(f"\nRecommended movies for '{user_preference}': {recommendations}")
# Out:
# Choose an option:
# 1. Enter a movie
# 2. Choose a genre
# Enter the number corresponding to your choice: 1
# Enter a movie: Barbie
#
# Recommended movies for 'Barbie': ['The Little Mermaid', 'The Flash', "The Three Musketeers - Part I: D'Artagnan", 'Spider-Man: Across the Spider-Verse', 'BlackBerry']

# %% [markdown]
# Certainly! Here's an explanation of the provided code:
#
# 1. **Data Loading and Preprocessing:**
#    - The code starts by loading a CSV file named 'moviesdataset_2023.csv' into a Pandas DataFrame (`df`).
#    - The 'genre' column, initially represented as a string, is converted to a list using the `literal_eval` function from the 'ast' module. This allows the code to handle the genre information as a list.
#
# 2. **User Interaction:**
#    - The user is prompted to choose between two options:
#       1. Enter a movie directly.
#       2. Choose a genre and then select a movie from the top movies in that genre based on vote count.
#    - The user's choice is stored in the variable `option`.
#
# 3. **User Input Handling:**
#    - If the user chooses option 1, they are prompted to enter the name of a movie (`user_preference`).
#    - If the user chooses option 2, they are presented with a list of unique genres extracted from the dataset, and they can choose a genre by entering the corresponding number. Then, the code filters movies based on the selected genre and displays the top movies in that genre based on vote count. The user is asked to choose a movie from the displayed list (`user_preference`).
#
# 4. **TF-IDF Vectorization:**
#    - The code uses the TF-IDF (Term Frequency-Inverse Document Frequency) vectorizer from scikit-learn to convert the combined features of 'genre' and 'description' into a TF-IDF matrix (`tfidf_matrix`).
#
# 5. **Cosine Similarity Calculation:**
#    - The code calculates the cosine similarity between movies using the TF-IDF matrix. The result is stored in the `cosine_similarities` matrix.
#
# 6. **Recommendation Function:**
#    - The function `get_recommendations` takes a movie title as input, retrieves the index of the movie in the DataFrame, and calculates the similarity scores with other movies. It then returns the top 5 recommended movies based on similarity.
#
# 7. **Generating Recommendations:**
#    - The code calls the `get_recommendations` function with the user's movie preference (`user_preference`) and prints the top 5 recommended movies based on content similarity.
#
# This code essentially provides a movie recommendation system where the user can input a movie directly or choose a genre and then select a movie from the top movies in that genre. The recommendations are generated using content-based filtering, leveraging TF-IDF and cosine similarity to find movies with similar content.

# %%
! pip install streamlit -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 12.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 20.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 46.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.5 MB/s eta 0:00:00

# %%
import urllib
print("Password/Enpoint IP for localtunnel is:",urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
# Out:
# Password/Enpoint IP for localtunnel is: 34.125.85.18

# %%
# !streamlit run movie_app.py & npx localtunnel --port 8501
# Out:
# [..................] / rollbackFailedOptional: verb npm-session 8596bfe8889e97c
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to False.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.125.85.18:8501
#
# npx: installed 22 in 6.389s
# your url is: https://busy-cameras-kneel.loca.lt
# 2024-01-12 20:39:27.534 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 535, in _run_script
#     exec(code, module.__dict__)
#   File "/content/movie_app.py", line 64, in <module>
#     recommendations = get_recommendations(user_preference)
#   File "/content/movie_app.py", line 56, in get_recommendations
#     movie_index = df[df['name'] == movie_title].index[0]
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py", line 5320, in __getitem__
#     return getitem(key)
# IndexError: index 0 is out of bounds for axis 0 with size 0
# 2024-01-12 20:39:42.657 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 535, in _run_script
#     exec(code, module.__dict__)
#   File "/content/movie_app.py", line 64, in <module>
#     recommendations = get_recommendations(user_preference)
#   File "/content/movie_app.py", line 56, in get_recommendations
#     movie_index = df[df['name'] == movie_title].index[0]
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py", line 5320, in __getitem__
#     return getitem(key)
# IndexError: index 0 is out of bounds for axis 0 with size 0
# 2024-01-12 20:39:51.553 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 535, in _run_script
#     exec(code, module.__dict__)
#   File "/content/movie_app.py", line 64, in <module>
#     recommendations = get_recommendations(user_preference)
#   File "/content/movie_app.py", line 56, in get_recommendations
#     movie_index = df[df['name'] == movie_title].index[0]
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py", line 5320, in __getitem__
#     return getitem(key)
# IndexError: index 0 is out of bounds for axis 0 with size 0
# 2024-01-12 20:39:59.423 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 535, in _run_script
#     exec(code, module.__dict__)
#   File "/content/movie_app.py", line 64, in <module>
#     recommendations = get_recommendations(user_preference)
#   File "/content/movie_app.py", line 56, in get_recommendations
#     movie_index = df[df['name'] == movie_title].index[0]
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py", line 5320, in __getitem__
#     return getitem(key)
# IndexError: index 0 is out of bounds for axis 0 with size 0
# 2024-01-12 20:40:20.308 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 535, in _run_script
#     exec(code, module.__dict__)
#   File "/content/movie_app.py", line 64, in <module>
#     recommendations = get_recommendations(user_preference)
#   File "/content/movie_app.py", line 56, in get_recommendations
#     movie_index = df[df['name'] == movie_title].index[0]
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py", line 5320, in __getitem__
#     return getitem(key)
# IndexError: index 0 is out of bounds for axis 0 with size 0
#   Stopping...
# ^C
